# %%
import numpy as np
cantSizes = 10;

# %%
mergeMean = np.zeros(cantSizes)
mergeWorst = np.zeros(cantSizes)
mergeBest = np.zeros(cantSizes)

insertionMean = np.zeros(cantSizes)
insertionWorst = np.zeros(cantSizes)
insertionBest = np.zeros(cantSizes)

selectionMean = np.zeros(cantSizes)
selectionWorst = np.zeros(cantSizes)
selectionBest = np.zeros(cantSizes)

# %%
f = open('cienmil.txt','r')
contenido = f.read()

# Iterar a través del contenido carácter por carácter
for i in range(len(contenido)):
    # Verificar si el carácter actual es un dígito o un punto decimal
    if contenido[i].isdigit() or contenido[i] == '.':
        # Si es así, construir una cadena que representa el número
        num_str = contenido[i]
        for j in range(i + 1, len(contenido)):
            if contenido[j].isdigit() or contenido[j] == '.':
                num_str += contenido[j]
            else:
                i = j
                break
        # Convertir la cadena a un valor de punto flotante y salir del bucle
        num = float(num_str)
        print("El próximo número flotante es:", num)
# Out:
# El próximo número flotante es: 10000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.001114
# El próximo número flotante es: 0.001114
# El próximo número flotante es: 1114000.0
# El próximo número flotante es: 1114000.0
# El próximo número flotante es: 1114000.0
# El próximo número flotante es: 114000.0
# El próximo número flotante es: 14000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00067
# El próximo número flotante es: 0.00067
# El próximo número flotante es: 670000.0
# El próximo número flotante es: 670000.0
# El próximo número flotante es: 670000.0
# El próximo número flotante es: 670000.0
# El próximo número flotante es: 70000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000669
# El próximo número flotante es: 0.000669
# El próximo número flotante es: 669000.0
# El próximo número flotante es: 669000.0
# El próximo número flotante es: 669000.0
# El próximo número flotante es: 669000.0
# El próximo número flotante es: 69000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.051029
# El próximo número flotante es: 0.051029
# El próximo número flotante es: 51029000.0
# El próximo número flotante es: 51029000.0
# El próximo número flotante es: 1029000.0
# El próximo número flotante es: 29000.0
# El próximo número flotante es: 29000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 2.8e-05
# El próximo número flotante es: 2.8e-05
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 8000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 2.8e-05
# El próximo número flotante es: 2.8e-05
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 28000.0
# El próximo número flotante es: 8000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.095219
# El próximo número flotante es: 0.095219
# El próximo número flotante es: 95219000.0
# El próximo número flotante es: 95219000.0
# El próximo número flotante es: 5219000.0
# El próximo número flotante es: 219000.0
# El próximo número flotante es: 19000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.094916
# El próximo número flotante es: 0.094916
# El próximo número flotante es: 94916000.0
# El próximo número flotante es: 94916000.0
# El próximo número flotante es: 4916000.0
# El próximo número flotante es: 916000.0
# El próximo número flotante es: 16000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.10387
# El próximo número flotante es: 0.10387
# El próximo número flotante es: 103870000.0
# El próximo número flotante es: 3870000.0
# El próximo número flotante es: 3870000.0
# El próximo número flotante es: 870000.0
# El próximo número flotante es: 70000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 20000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00227
# El próximo número flotante es: 0.00227
# El próximo número flotante es: 2270000.0
# El próximo número flotante es: 2270000.0
# El próximo número flotante es: 2270000.0
# El próximo número flotante es: 270000.0
# El próximo número flotante es: 70000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00142
# El próximo número flotante es: 0.00142
# El próximo número flotante es: 1420000.0
# El próximo número flotante es: 1420000.0
# El próximo número flotante es: 1420000.0
# El próximo número flotante es: 420000.0
# El próximo número flotante es: 20000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.001386
# El próximo número flotante es: 0.001386
# El próximo número flotante es: 1386000.0
# El próximo número flotante es: 1386000.0
# El próximo número flotante es: 1386000.0
# El próximo número flotante es: 386000.0
# El próximo número flotante es: 86000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.199225
# El próximo número flotante es: 0.199225
# El próximo número flotante es: 199225000.0
# El próximo número flotante es: 99225000.0
# El próximo número flotante es: 9225000.0
# El próximo número flotante es: 225000.0
# El próximo número flotante es: 25000.0
# El próximo número flotante es: 5000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 5.6e-05
# El próximo número flotante es: 5.6e-05
# El próximo número flotante es: 56000.0
# El próximo número flotante es: 56000.0
# El próximo número flotante es: 56000.0
# El próximo número flotante es: 56000.0
# El próximo número flotante es: 56000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 5.4e-05
# El próximo número flotante es: 5.4e-05
# El próximo número flotante es: 54000.0
# El próximo número flotante es: 54000.0
# El próximo número flotante es: 54000.0
# El próximo número flotante es: 54000.0
# El próximo número flotante es: 54000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.374671
# El próximo número flotante es: 0.374671
# El próximo número flotante es: 374671000.0
# El próximo número flotante es: 74671000.0
# El próximo número flotante es: 4671000.0
# El próximo número flotante es: 671000.0
# El próximo número flotante es: 71000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.377151
# El próximo número flotante es: 0.377151
# El próximo número flotante es: 377151000.0
# El próximo número flotante es: 77151000.0
# El próximo número flotante es: 7151000.0
# El próximo número flotante es: 151000.0
# El próximo número flotante es: 51000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.376157
# El próximo número flotante es: 0.376157
# El próximo número flotante es: 376157000.0
# El próximo número flotante es: 76157000.0
# El próximo número flotante es: 6157000.0
# El próximo número flotante es: 157000.0
# El próximo número flotante es: 57000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 30000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.003426
# El próximo número flotante es: 0.003426
# El próximo número flotante es: 3426000.0
# El próximo número flotante es: 3426000.0
# El próximo número flotante es: 3426000.0
# El próximo número flotante es: 426000.0
# El próximo número flotante es: 26000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.002164
# El próximo número flotante es: 0.002164
# El próximo número flotante es: 2164000.0
# El próximo número flotante es: 2164000.0
# El próximo número flotante es: 2164000.0
# El próximo número flotante es: 164000.0
# El próximo número flotante es: 64000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.002204
# El próximo número flotante es: 0.002204
# El próximo número flotante es: 2204000.0
# El próximo número flotante es: 2204000.0
# El próximo número flotante es: 2204000.0
# El próximo número flotante es: 204000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.444352
# El próximo número flotante es: 0.444352
# El próximo número flotante es: 444352000.0
# El próximo número flotante es: 44352000.0
# El próximo número flotante es: 4352000.0
# El próximo número flotante es: 352000.0
# El próximo número flotante es: 52000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 8.2e-05
# El próximo número flotante es: 8.2e-05
# El próximo número flotante es: 82000.0
# El próximo número flotante es: 82000.0
# El próximo número flotante es: 82000.0
# El próximo número flotante es: 82000.0
# El próximo número flotante es: 82000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 8.4e-05
# El próximo número flotante es: 8.4e-05
# El próximo número flotante es: 84000.0
# El próximo número flotante es: 84000.0
# El próximo número flotante es: 84000.0
# El próximo número flotante es: 84000.0
# El próximo número flotante es: 84000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.837461
# El próximo número flotante es: 0.837461
# El próximo número flotante es: 837461000.0
# El próximo número flotante es: 37461000.0
# El próximo número flotante es: 7461000.0
# El próximo número flotante es: 461000.0
# El próximo número flotante es: 61000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.838092
# El próximo número flotante es: 0.838092
# El próximo número flotante es: 838092000.0
# El próximo número flotante es: 38092000.0
# El próximo número flotante es: 8092000.0
# El próximo número flotante es: 92000.0
# El próximo número flotante es: 92000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.851152
# El próximo número flotante es: 0.851152
# El próximo número flotante es: 851152000.0
# El próximo número flotante es: 51152000.0
# El próximo número flotante es: 1152000.0
# El próximo número flotante es: 152000.0
# El próximo número flotante es: 52000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 40000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.004582
# El próximo número flotante es: 0.004582
# El próximo número flotante es: 4582000.0
# El próximo número flotante es: 4582000.0
# El próximo número flotante es: 4582000.0
# El próximo número flotante es: 582000.0
# El próximo número flotante es: 82000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.002937
# El próximo número flotante es: 0.002937
# El próximo número flotante es: 2937000.0
# El próximo número flotante es: 2937000.0
# El próximo número flotante es: 2937000.0
# El próximo número flotante es: 937000.0
# El próximo número flotante es: 37000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.002936
# El próximo número flotante es: 0.002936
# El próximo número flotante es: 2936000.0
# El próximo número flotante es: 2936000.0
# El próximo número flotante es: 2936000.0
# El próximo número flotante es: 936000.0
# El próximo número flotante es: 36000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.793006
# El próximo número flotante es: 0.793006
# El próximo número flotante es: 793006000.0
# El próximo número flotante es: 93006000.0
# El próximo número flotante es: 3006000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00011
# El próximo número flotante es: 0.00011
# El próximo número flotante es: 110000.0
# El próximo número flotante es: 110000.0
# El próximo número flotante es: 110000.0
# El próximo número flotante es: 110000.0
# El próximo número flotante es: 10000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000108
# El próximo número flotante es: 0.000108
# El próximo número flotante es: 108000.0
# El próximo número flotante es: 108000.0
# El próximo número flotante es: 108000.0
# El próximo número flotante es: 108000.0
# El próximo número flotante es: 8000.0
# El próximo número flotante es: 8000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 1.491849
# El próximo número flotante es: 0.491849
# El próximo número flotante es: 491849000.0
# El próximo número flotante es: 91849000.0
# El próximo número flotante es: 1849000.0
# El próximo número flotante es: 849000.0
# El próximo número flotante es: 49000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 1.49302
# El próximo número flotante es: 0.49302
# El próximo número flotante es: 493020000.0
# El próximo número flotante es: 93020000.0
# El próximo número flotante es: 3020000.0
# El próximo número flotante es: 20000.0
# El próximo número flotante es: 20000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 1.494127
# El próximo número flotante es: 0.494127
# El próximo número flotante es: 494127000.0
# El próximo número flotante es: 94127000.0
# El próximo número flotante es: 4127000.0
# El próximo número flotante es: 127000.0
# El próximo número flotante es: 27000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 50000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.005696
# El próximo número flotante es: 0.005696
# El próximo número flotante es: 5696000.0
# El próximo número flotante es: 5696000.0
# El próximo número flotante es: 5696000.0
# El próximo número flotante es: 696000.0
# El próximo número flotante es: 96000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.003825
# El próximo número flotante es: 0.003825
# El próximo número flotante es: 3825000.0
# El próximo número flotante es: 3825000.0
# El próximo número flotante es: 3825000.0
# El próximo número flotante es: 825000.0
# El próximo número flotante es: 25000.0
# El próximo número flotante es: 5000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.004073
# El próximo número flotante es: 0.004073
# El próximo número flotante es: 4073000.0
# El próximo número flotante es: 4073000.0
# El próximo número flotante es: 4073000.0
# El próximo número flotante es: 73000.0
# El próximo número flotante es: 73000.0
# El próximo número flotante es: 3000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 1.241818
# El próximo número flotante es: 0.241818
# El próximo número flotante es: 241818000.0
# El próximo número flotante es: 41818000.0
# El próximo número flotante es: 1818000.0
# El próximo número flotante es: 818000.0
# El próximo número flotante es: 18000.0
# El próximo número flotante es: 8000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00014
# El próximo número flotante es: 0.00014
# El próximo número flotante es: 140000.0
# El próximo número flotante es: 140000.0
# El próximo número flotante es: 140000.0
# El próximo número flotante es: 140000.0
# El próximo número flotante es: 40000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000139
# El próximo número flotante es: 0.000139
# El próximo número flotante es: 139000.0
# El próximo número flotante es: 139000.0
# El próximo número flotante es: 139000.0
# El próximo número flotante es: 139000.0
# El próximo número flotante es: 39000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 2.331247
# El próximo número flotante es: 0.331247
# El próximo número flotante es: 331247000.0
# El próximo número flotante es: 31247000.0
# El próximo número flotante es: 1247000.0
# El próximo número flotante es: 247000.0
# El próximo número flotante es: 47000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 2.32757
# El próximo número flotante es: 0.32757
# El próximo número flotante es: 327570000.0
# El próximo número flotante es: 27570000.0
# El próximo número flotante es: 7570000.0
# El próximo número flotante es: 570000.0
# El próximo número flotante es: 70000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 2.32534
# El próximo número flotante es: 0.32534
# El próximo número flotante es: 325340000.0
# El próximo número flotante es: 25340000.0
# El próximo número flotante es: 5340000.0
# El próximo número flotante es: 340000.0
# El próximo número flotante es: 40000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 60000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.007
# El próximo número flotante es: 0.007
# El próximo número flotante es: 7000000.0
# El próximo número flotante es: 7000000.0
# El próximo número flotante es: 7000000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.004786
# El próximo número flotante es: 0.004786
# El próximo número flotante es: 4786000.0
# El próximo número flotante es: 4786000.0
# El próximo número flotante es: 4786000.0
# El próximo número flotante es: 786000.0
# El próximo número flotante es: 86000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.004571
# El próximo número flotante es: 0.004571
# El próximo número flotante es: 4571000.0
# El próximo número flotante es: 4571000.0
# El próximo número flotante es: 4571000.0
# El próximo número flotante es: 571000.0
# El próximo número flotante es: 71000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 1.798425
# El próximo número flotante es: 0.798425
# El próximo número flotante es: 798425000.0
# El próximo número flotante es: 98425000.0
# El próximo número flotante es: 8425000.0
# El próximo número flotante es: 425000.0
# El próximo número flotante es: 25000.0
# El próximo número flotante es: 5000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000174
# El próximo número flotante es: 0.000174
# El próximo número flotante es: 174000.0
# El próximo número flotante es: 174000.0
# El próximo número flotante es: 174000.0
# El próximo número flotante es: 174000.0
# El próximo número flotante es: 74000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000164
# El próximo número flotante es: 0.000164
# El próximo número flotante es: 164000.0
# El próximo número flotante es: 164000.0
# El próximo número flotante es: 164000.0
# El próximo número flotante es: 164000.0
# El próximo número flotante es: 64000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 3.365517
# El próximo número flotante es: 0.365517
# El próximo número flotante es: 365517000.0
# El próximo número flotante es: 65517000.0
# El próximo número flotante es: 5517000.0
# El próximo número flotante es: 517000.0
# El próximo número flotante es: 17000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 3.37658
# El próximo número flotante es: 0.37658
# El próximo número flotante es: 376580000.0
# El próximo número flotante es: 76580000.0
# El próximo número flotante es: 6580000.0
# El próximo número flotante es: 580000.0
# El próximo número flotante es: 80000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 3.352117
# El próximo número flotante es: 0.352117
# El próximo número flotante es: 352117000.0
# El próximo número flotante es: 52117000.0
# El próximo número flotante es: 2117000.0
# El próximo número flotante es: 117000.0
# El próximo número flotante es: 17000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 70000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.008331
# El próximo número flotante es: 0.008331
# El próximo número flotante es: 8331000.0
# El próximo número flotante es: 8331000.0
# El próximo número flotante es: 8331000.0
# El próximo número flotante es: 331000.0
# El próximo número flotante es: 31000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.005512
# El próximo número flotante es: 0.005512
# El próximo número flotante es: 5512000.0
# El próximo número flotante es: 5512000.0
# El próximo número flotante es: 5512000.0
# El próximo número flotante es: 512000.0
# El próximo número flotante es: 12000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.005513
# El próximo número flotante es: 0.005513
# El próximo número flotante es: 5513000.0
# El próximo número flotante es: 5513000.0
# El próximo número flotante es: 5513000.0
# El próximo número flotante es: 513000.0
# El próximo número flotante es: 13000.0
# El próximo número flotante es: 3000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 2.42458
# El próximo número flotante es: 0.42458
# El próximo número flotante es: 424580000.0
# El próximo número flotante es: 24580000.0
# El próximo número flotante es: 4580000.0
# El próximo número flotante es: 580000.0
# El próximo número flotante es: 80000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00019
# El próximo número flotante es: 0.00019
# El próximo número flotante es: 190000.0
# El próximo número flotante es: 190000.0
# El próximo número flotante es: 190000.0
# El próximo número flotante es: 190000.0
# El próximo número flotante es: 90000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000191
# El próximo número flotante es: 0.000191
# El próximo número flotante es: 191000.0
# El próximo número flotante es: 191000.0
# El próximo número flotante es: 191000.0
# El próximo número flotante es: 191000.0
# El próximo número flotante es: 91000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 4.56767
# El próximo número flotante es: 0.56767
# El próximo número flotante es: 567670000.0
# El próximo número flotante es: 67670000.0
# El próximo número flotante es: 7670000.0
# El próximo número flotante es: 670000.0
# El próximo número flotante es: 70000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 4.580314
# El próximo número flotante es: 0.580314
# El próximo número flotante es: 580314000.0
# El próximo número flotante es: 80314000.0
# El próximo número flotante es: 314000.0
# El próximo número flotante es: 314000.0
# El próximo número flotante es: 14000.0
# El próximo número flotante es: 4000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 4.567066
# El próximo número flotante es: 0.567066
# El próximo número flotante es: 567066000.0
# El próximo número flotante es: 67066000.0
# El próximo número flotante es: 7066000.0
# El próximo número flotante es: 66000.0
# El próximo número flotante es: 66000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 80000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.009637
# El próximo número flotante es: 0.009637
# El próximo número flotante es: 9637000.0
# El próximo número flotante es: 9637000.0
# El próximo número flotante es: 9637000.0
# El próximo número flotante es: 637000.0
# El próximo número flotante es: 37000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.006405
# El próximo número flotante es: 0.006405
# El próximo número flotante es: 6405000.0
# El próximo número flotante es: 6405000.0
# El próximo número flotante es: 6405000.0
# El próximo número flotante es: 405000.0
# El próximo número flotante es: 5000.0
# El próximo número flotante es: 5000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.00629
# El próximo número flotante es: 0.00629
# El próximo número flotante es: 6290000.0
# El próximo número flotante es: 6290000.0
# El próximo número flotante es: 6290000.0
# El próximo número flotante es: 290000.0
# El próximo número flotante es: 90000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 3.191283
# El próximo número flotante es: 0.191283
# El próximo número flotante es: 191283000.0
# El próximo número flotante es: 91283000.0
# El próximo número flotante es: 1283000.0
# El próximo número flotante es: 283000.0
# El próximo número flotante es: 83000.0
# El próximo número flotante es: 3000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000218
# El próximo número flotante es: 0.000218
# El próximo número flotante es: 218000.0
# El próximo número flotante es: 218000.0
# El próximo número flotante es: 218000.0
# El próximo número flotante es: 218000.0
# El próximo número flotante es: 18000.0
# El próximo número flotante es: 8000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000217
# El próximo número flotante es: 0.000217
# El próximo número flotante es: 217000.0
# El próximo número flotante es: 217000.0
# El próximo número flotante es: 217000.0
# El próximo número flotante es: 217000.0
# El próximo número flotante es: 17000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 5.970355
# El próximo número flotante es: 0.970355
# El próximo número flotante es: 970355000.0
# El próximo número flotante es: 70355000.0
# El próximo número flotante es: 355000.0
# El próximo número flotante es: 355000.0
# El próximo número flotante es: 55000.0
# El próximo número flotante es: 5000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 5.9535
# El próximo número flotante es: 0.9535
# El próximo número flotante es: 953500000.0
# El próximo número flotante es: 53500000.0
# El próximo número flotante es: 3500000.0
# El próximo número flotante es: 500000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 5.989357
# El próximo número flotante es: 0.989357
# El próximo número flotante es: 989357000.0
# El próximo número flotante es: 89357000.0
# El próximo número flotante es: 9357000.0
# El próximo número flotante es: 357000.0
# El próximo número flotante es: 57000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 90000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.011259
# El próximo número flotante es: 0.011259
# El próximo número flotante es: 11259000.0
# El próximo número flotante es: 11259000.0
# El próximo número flotante es: 1259000.0
# El próximo número flotante es: 259000.0
# El próximo número flotante es: 59000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.007236
# El próximo número flotante es: 0.007236
# El próximo número flotante es: 7236000.0
# El próximo número flotante es: 7236000.0
# El próximo número flotante es: 7236000.0
# El próximo número flotante es: 236000.0
# El próximo número flotante es: 36000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.007229
# El próximo número flotante es: 0.007229
# El próximo número flotante es: 7229000.0
# El próximo número flotante es: 7229000.0
# El próximo número flotante es: 7229000.0
# El próximo número flotante es: 229000.0
# El próximo número flotante es: 29000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 4.036621
# El próximo número flotante es: 0.036621
# El próximo número flotante es: 36621000.0
# El próximo número flotante es: 36621000.0
# El próximo número flotante es: 6621000.0
# El próximo número flotante es: 621000.0
# El próximo número flotante es: 21000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000252
# El próximo número flotante es: 0.000252
# El próximo número flotante es: 252000.0
# El próximo número flotante es: 252000.0
# El próximo número flotante es: 252000.0
# El próximo número flotante es: 252000.0
# El próximo número flotante es: 52000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000246
# El próximo número flotante es: 0.000246
# El próximo número flotante es: 246000.0
# El próximo número flotante es: 246000.0
# El próximo número flotante es: 246000.0
# El próximo número flotante es: 246000.0
# El próximo número flotante es: 46000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 7.540529
# El próximo número flotante es: 0.540529
# El próximo número flotante es: 540529000.0
# El próximo número flotante es: 40529000.0
# El próximo número flotante es: 529000.0
# El próximo número flotante es: 529000.0
# El próximo número flotante es: 29000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 7.550613
# El próximo número flotante es: 0.550613
# El próximo número flotante es: 550613000.0
# El próximo número flotante es: 50613000.0
# El próximo número flotante es: 613000.0
# El próximo número flotante es: 613000.0
# El próximo número flotante es: 13000.0
# El próximo número flotante es: 3000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 7.530557
# El próximo número flotante es: 0.530557
# El próximo número flotante es: 530557000.0
# El próximo número flotante es: 30557000.0
# El próximo número flotante es: 557000.0
# El próximo número flotante es: 557000.0
# El próximo número flotante es: 57000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 100000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.012227
# El próximo número flotante es: 0.012227
# El próximo número flotante es: 12227000.0
# El próximo número flotante es: 12227000.0
# El próximo número flotante es: 2227000.0
# El próximo número flotante es: 227000.0
# El próximo número flotante es: 27000.0
# El próximo número flotante es: 7000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.007953
# El próximo número flotante es: 0.007953
# El próximo número flotante es: 7953000.0
# El próximo número flotante es: 7953000.0
# El próximo número flotante es: 7953000.0
# El próximo número flotante es: 953000.0
# El próximo número flotante es: 53000.0
# El próximo número flotante es: 3000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.008049
# El próximo número flotante es: 0.008049
# El próximo número flotante es: 8049000.0
# El próximo número flotante es: 8049000.0
# El próximo número flotante es: 8049000.0
# El próximo número flotante es: 49000.0
# El próximo número flotante es: 49000.0
# El próximo número flotante es: 9000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 4.979641
# El próximo número flotante es: 0.979641
# El próximo número flotante es: 979641000.0
# El próximo número flotante es: 79641000.0
# El próximo número flotante es: 9641000.0
# El próximo número flotante es: 641000.0
# El próximo número flotante es: 41000.0
# El próximo número flotante es: 1000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000272
# El próximo número flotante es: 0.000272
# El próximo número flotante es: 272000.0
# El próximo número flotante es: 272000.0
# El próximo número flotante es: 272000.0
# El próximo número flotante es: 272000.0
# El próximo número flotante es: 72000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.000283
# El próximo número flotante es: 0.000283
# El próximo número flotante es: 283000.0
# El próximo número flotante es: 283000.0
# El próximo número flotante es: 283000.0
# El próximo número flotante es: 283000.0
# El próximo número flotante es: 83000.0
# El próximo número flotante es: 3000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 9.304972
# El próximo número flotante es: 0.304972
# El próximo número flotante es: 304972000.0
# El próximo número flotante es: 4972000.0
# El próximo número flotante es: 4972000.0
# El próximo número flotante es: 972000.0
# El próximo número flotante es: 72000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 9.302796
# El próximo número flotante es: 0.302796
# El próximo número flotante es: 302796000.0
# El próximo número flotante es: 2796000.0
# El próximo número flotante es: 2796000.0
# El próximo número flotante es: 796000.0
# El próximo número flotante es: 96000.0
# El próximo número flotante es: 6000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 9.312632
# El próximo número flotante es: 0.312632
# El próximo número flotante es: 312632000.0
# El próximo número flotante es: 12632000.0
# El próximo número flotante es: 2632000.0
# El próximo número flotante es: 632000.0
# El próximo número flotante es: 32000.0
# El próximo número flotante es: 2000.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0
# El próximo número flotante es: 0.0

# %%
for i in range(cantSizes):
    mergeMean[i] = np.zeros(cantSizes)
    mergeWorst[i] = np.zeros(cantSizes)
    mergeBest[i] = np.zeros(cantSizes)
